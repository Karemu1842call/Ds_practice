# %% [markdown]
# GDP Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
country_codes = pd.read_csv('country_codes.csv')
gdpdata = pd.read_csv('gdp_data.csv')
merged_table =pd.merge(country_codes,gdpdata,on='country_code', how='inner')
merged_table
# Out:
#       country_code                     region         income_group  \
# 0              ABW  Latin America & Caribbean          High income
# 1              ABW  Latin America & Caribbean          High income
# 2              ABW  Latin America & Caribbean          High income
# 3              ABW  Latin America & Caribbean          High income
# 4              ABW  Latin America & Caribbean          High income
# ...            ...                        ...                  ...
# 10543          ZWE         Sub-Saharan Africa  Lower middle income
# 10544          ZWE         Sub-Saharan Africa  Lower middle income
# 10545          ZWE         Sub-Saharan Africa  Lower middle income
# 10546          ZWE         Sub-Saharan Africa  Lower middle income
# 10547          ZWE         Sub-Saharan Africa  Lower middle income
#
#       country_name  year         value
# 0            Aruba  1986  4.055866e+08
# 1            Aruba  1987  4.877095e+08
# 2            Aruba  1988  5.966480e+08
# ...

# %% [markdown]
# A Graph of Worlds GDP Growth Since 1960

# %%
# Group by "years" and calculate the total "value" for each year
yearly_total_gdp = gdpdata.groupby("year")["value"].sum().reset_index()

# Sort the DataFrame by total "value" in descending order
yearly_total_gdp = yearly_total_gdp.sort_values(by="value", ascending=False)

# Create a bar plot
plt.figure(figsize=(15, 7))
sns.barplot(x="year", y="value", data=gdpdata, palette="viridis")
plt.xlabel("Year")
plt.ylabel("Total GDP}")
plt.title("World GDP Groth Over the Years")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
russia_data = merged_table.loc[merged_table['country_code']=='RUS']
plt.figure(figsize=(15, 7))
sns.barplot(x="year", y="value", data=russia_data, palette="viridis")
plt.xlabel("Year")
plt.ylabel("Total GDP}")
plt.title("Russia GDP Groth Over the Years")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
us_gdp = merged_table.loc[merged_table['country_code']=='USA']
plt.figure(figsize=(15, 7))
sns.barplot(x="year", y="value", data=us_gdp, palette="viridis")
plt.xlabel("Year")
plt.ylabel("Total GDP}")
plt.title("Russia GDP Groth Over the Years")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Kenyas Table

# %%
kenyadata= gdpdata.loc[gdpdata['country_code']== 'KEN']
kenya_gdp = kenyadata.groupby("year")["value"].sum().reset_index()

# Sort the DataFrame by total "value" in descending order
kenya_gdp = kenya_gdp.sort_values(by="value", ascending=False)
kenya_gdp
# Out:
#     year         value
# 62  2022  1.130000e+11
# 61  2021  1.100000e+11
# 60  2020  1.010000e+11
# 59  2019  1.000000e+11
# 58  2018  9.220298e+10
# ..   ...           ...
# 5   1965  9.979193e+08
# 3   1963  9.265893e+08
# 2   1962  8.681114e+08
# 1   1961  7.929595e+08
# 0   1960  7.912655e+08
#
# [63 rows x 2 columns]

# %%
plt.figure(figsize=(15, 7))
sns.barplot(x="year", y="value", data=kenya_gdp, palette="viridis")
plt.xlabel("Year")
plt.ylabel("Total GDP}")
plt.title("Kenya GDP Groth Over the Years")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/karemu200018/code/Kratos/python/Data_science/videogames/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# A Query of Data from 2022 only.

# %%
gdpdata.query('year == 2022')
# Out:
#                       country_name country_code  year         value
# 104    Africa Eastern and Southern          AFE  2022  1.170000e+12
# 167     Africa Western and Central          AFW  2022  8.780000e+11
# 206                        Albania          ALB  2022  1.888210e+10
# 269                        Algeria          DZA  2022  1.920000e+11
# 342                        Andorra          AND  2022  3.352033e+09
# ...                            ...          ...   ...           ...
# 13098                      Vietnam          VNM  2022  4.090000e+11
# 13146           West Bank and Gaza          PSE  2022  1.911190e+10
# 13209                        World          WLD  2022  1.010000e+14
# 13301                       Zambia          ZMB  2022  2.978445e+10
# 13364                     Zimbabwe          ZWE  2022  2.067806e+10
#
# [233 rows x 4 columns]

# %%
gdpdata.sort_values(by='year', ascending=False)
# Out:
#       country_name country_code  year         value
# 13364     Zimbabwe          ZWE  2022  2.067806e+10
# 13098      Vietnam          VNM  2022  4.090000e+11
# 11752        Sudan          SDN  2022  5.166224e+10
# 6060        Israel          ISR  2022  5.220000e+11
# 5996       Ireland          IRL  2022  5.290000e+11
# ...            ...          ...   ...           ...
# 5934       Ireland          IRL  1960  1.939330e+09
# 6023        Israel          ISR  1960  2.887229e+09
# 6061         Italy          ITA  1960  4.038529e+10
# 11753     Suriname          SUR  1960  9.965000e+07
# 0      Afghanistan          AFG  1960  5.377778e+08
#
# [13365 rows x 4 columns]

# %% [markdown]
# Average GDP based on years.

# %%
country_data= gdpdata.groupby('year')
average_years = country_data['value'].mean()
average_years
# Out:
# year
# 1960    7.120593e+10
# 1961    7.276254e+10
# 1962    7.639902e+10
# 1963    8.235778e+10
# 1964    9.056508e+10
#             ...
# 2018    2.773668e+12
# 2019    2.826055e+12
# 2020    2.739428e+12
# 2021    3.211347e+12
# 2022    3.601926e+12
# Name: value, Length: 63, dtype: float64

# %%
years = sorted(merged_table['year'].unique().tolist())
def make_plot_data() -> dict:
    plot_df = merged_table
    data = [dict(type='choropleth', locations = plot_df[plot_df['year'] == year]['country_code'], 
                 z=plot_df[plot_df['year'] == year]['value'],
                 hovertext=plot_df[plot_df['year'] == year]['country_name']) for year in years]
    steps = [dict(method='restyle', args=['visible', [other == year for other in years]], label=year) for year in years]
    layout = dict(geo=dict(scope='world'), sliders=[dict(active=0, pad={'t': 1}, steps=steps)], title="World GDP by Country Over the Years")
    return dict(data=data, layout=layout)

from plotly.offline import init_notebook_mode, iplot

init_notebook_mode(connected=True)
iplot(make_plot_data())
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...
